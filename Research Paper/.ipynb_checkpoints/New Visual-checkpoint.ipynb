# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
def dropper(df):
    nan_value = float("NaN")
    df.replace(0.0, nan_value, inplace=True)
    return df

# %%
def get_info():
    df = pd.read_csv('Databases/Test_file.csv')
#     for row in df.itertuples():
#         if row.Origin == row.Destination:
#             df = df.drop(labels=row.Index, axis=0)
    df['Distance'] = df['Distance'].str.split().str.get(-1)
    df['Distance'] = pd.to_numeric(df['Distance'], errors='coerce')
    df = dropper(df)
    df = df.dropna()
    return df

# %% [markdown]
# ## Note
# I need to ask Henry about the value of dropping the observation that contains intramunicipality commuting as opposed to keeping it, making distance decay stronger

# %%
def stat_plotter(df, i):
    
    # First Graph: Origin - Distance Plot
    plt.figure(figsize=(5, 5))
    ax = plt.axes()
    ax.scatter(df["Distance"], df["Origin Pop"], color='b', alpha=0.20)
    ax.set_xlabel('Distance')
    ax.set_ylabel('Origin Pop')
    plt.gcf()
    plt.savefig('Results/OrDistance' + str(i) + '.png')
    plt.close()
    
    # Second Graph: Destination - Distance Plot
    plt.figure(figsize=(5, 5))
    ax = plt.axes()
    ax.scatter(df["Distance"], df["Destination Pop"], color='b', alpha=0.20)
    ax.set_xlabel('Distance')
    ax.set_ylabel('Destination Pop')
    plt.gcf()
    plt.savefig('Results/DestDistance' + str(i) + '.png')
    plt.close()
    
    # Third Graph: Distance - Commuters Plot
    plt.figure(figsize=(5, 5))
    ax = plt.axes()
    ax.scatter(df["Distance"], df["Commuters"], color='b', alpha=0.20)
    ax.set_xlabel('Distance')
    ax.set_ylabel('Commuters')
    plt.gcf()
    plt.savefig('Results/DistCom' + str(i) + '.png')
    plt.close()
    
    # Fourth Graph: Destination - Commuters Plot
    plt.figure(figsize=(5, 5))
    ax = plt.axes()
    ax.scatter(df["Destination Pop"], df["Commuters"], color='b', alpha=0.20)
    ax.set_xlabel('Destination Pop')
    ax.set_ylabel('Commuters')
    plt.gcf()
    plt.savefig('Results/DestCom' + str(i) + '.png')
    plt.close()
    
    # Fifth Graph: Origin - Commuters Plot
    plt.figure(figsize=(5, 5))
    ax = plt.axes()
    ax.scatter(df["Origin Pop"], df["Commuters"], color='b', alpha=0.20)
    ax.set_xlabel('Origin Pop')
    ax.set_ylabel('Commuters')
    plt.gcf()
    plt.savefig('Results/OrCom' + str(i) + '.png')
    plt.close()

# %%
def descriptive_stats(df):
    df = df.astype(int)
    del df['Origin']
    del df['Destination']
    print(df.describe()\, '\n')
    print(df.corr(), '\n', df.cov(), '\n\n')
    stat_plotter(df, "General")
    for i in range(2014, 2021, 1):
        print("Descriptive Statistics of %s \n" % i)
        df1 = df[df['Year'] == i]
        del df1['Year']
        print(df1.describe(), '\n')
        print(df1.corr(), '\n', df1.cov(), '\n\n')
        stat_plotter(df1, i)
    return

# %%
df = get_info()

# %%
descriptive_stats(df)
# Out:
# Descriptive Statistics of 2014
#
#            Commuters      Distance     Origin Pop  Destination Pop
# count   11730.000000  11730.000000   11730.000000     11730.000000
# mean      596.419437     42.411168   80479.500597    112532.101620
# std      3460.529417     37.544417  128206.144581    165909.391775
# min       100.000000      0.000000    1509.000000      1509.000000
# 25%       100.000000     16.000000   23702.000000     26703.000000
# 50%       100.000000     30.000000   38879.000000     48216.000000
# 75%       400.000000     57.000000   79611.000000    121562.000000
# max    247200.000000    303.000000  821752.000000    821752.000000
#
#                  Commuters  Distance  Origin Pop  Destination Pop
# Commuters         1.000000 -0.110146    0.094849         0.085140
# Distance         -0.110146  1.000000    0.178331         0.389123
# Origin Pop        0.094849  0.178331    1.000000        -0.066395
# Destination Pop   0.085140  0.389123   -0.066395         1.000000
#                      Commuters      Distance    Origin Pop  Destination Pop
# Commuters        1.197526e+07 -1.431055e+04  4.208093e+07     4.888166e+07
# Distance        -1.431055e+04  1.409583e+03  8.583852e+05     2.423835e+06
# Origin Pop       4.208093e+07  8.583852e+05  1.643682e+10    -1.412262e+09
# Destination Pop  4.888166e+07  2.423835e+06 -1.412262e+09     2.752593e+10
#
#
# Descriptive Statistics of 2015
#
#            Commuters      Distance     Origin Pop  Destination Pop
# count   11667.000000  11667.000000   11667.000000     11667.000000
# mean      608.948316     42.568184   81086.711751    112790.315762
# std      3575.989584     37.391659  128355.086924    165949.877951
# min       100.000000      0.000000    1498.000000       919.000000
# 25%       100.000000     17.000000   24332.000000     27467.000000
# 50%       100.000000     31.000000   39657.000000     48506.000000
# 75%       400.000000     57.000000   81075.000000    122533.000000
# max    256800.000000    262.000000  833624.000000    833624.000000
#
#                  Commuters  Distance  Origin Pop  Destination Pop
# Commuters         1.000000 -0.110283    0.096313         0.087958
# Distance         -0.110283  1.000000    0.168234         0.388648
# Origin Pop        0.096313  0.168234    1.000000        -0.062429
# Destination Pop   0.087958  0.388648   -0.062429         1.000000
#                      Commuters      Distance    Origin Pop  Destination Pop
# Commuters        1.278770e+07 -1.474623e+04  4.420755e+07     5.219721e+07
# Distance        -1.474623e+04  1.398136e+03  8.074226e+05     2.411614e+06
# Origin Pop       4.420755e+07  8.074226e+05  1.647503e+10    -1.329774e+09
# Destination Pop  5.219721e+07  2.411614e+06 -1.329774e+09     2.753936e+10
#
#
# Descriptive Statistics of 2016
#
#            Commuters      Distance     Origin Pop  Destination Pop
# count   11715.000000  11715.000000   11715.000000     11715.000000
# mean      617.533077     42.318054   81184.637217    112917.076312
# std      3606.703189     36.872734  128888.985876    165721.551609
# min       100.000000      0.000000    1498.000000       941.000000
# 25%       100.000000     17.000000   24428.000000     27728.000000
# 50%       100.000000     31.000000   40709.000000     49300.000000
# 75%       400.000000     56.000000   79928.000000    123661.000000
# max    258000.000000    260.000000  844947.000000    844947.000000
#
#                  Commuters  Distance  Origin Pop  Destination Pop
# Commuters         1.000000 -0.111212    0.098846         0.090342
# Distance         -0.111212  1.000000    0.173378         0.395814
# Origin Pop        0.098846  0.173378    1.000000        -0.057667
# Destination Pop   0.090342  0.395814   -0.057667         1.000000
#                      Commuters      Distance    Origin Pop  Destination Pop
# Commuters        1.300831e+07 -1.478994e+04  4.595003e+07     5.399837e+07
# Distance        -1.478994e+04  1.359599e+03  8.239787e+05     2.418666e+06
# Origin Pop       4.595003e+07  8.239787e+05  1.661237e+10    -1.231746e+09
# Destination Pop  5.399837e+07  2.418666e+06 -1.231746e+09     2.746363e+10
#
#
# Descriptive Statistics of 2017
#
#            Commuters      Distance     Origin Pop  Destination Pop
# count   11807.000000  11807.000000   11807.000000     11807.000000
# mean      630.761413     41.678496   82671.822817    112367.304904
# std      3686.436989     35.435627  131321.926397    165412.786871
# min       100.000000      0.000000    1575.000000       932.000000
# 25%       100.000000     17.000000   24911.000000     28014.000000
# 50%       100.000000     31.000000   40847.000000     49855.000000
# 75%       400.000000     56.000000   80593.000000    122723.000000
# max    266100.000000    259.000000  854047.000000    854047.000000
#
#                  Commuters  Distance  Origin Pop  Destination Pop
# Commuters         1.000000 -0.113397    0.097579         0.092623
# Distance         -0.113397  1.000000    0.188661         0.396048
# Origin Pop        0.097579  0.188661    1.000000        -0.056007
# Destination Pop   0.092623  0.396048   -0.056007         1.000000
#                      Commuters      Distance    Origin Pop  Destination Pop
# Commuters        1.358982e+07 -1.481320e+04  4.723895e+07     5.647989e+07
# Distance        -1.481320e+04  1.255684e+03  8.779280e+05     2.321436e+06
# Origin Pop       4.723895e+07  8.779280e+05  1.724545e+10    -1.216597e+09
# Destination Pop  5.647989e+07  2.321436e+06 -1.216597e+09     2.736139e+10
#
#
# Descriptive Statistics of 2018
#
#            Commuters      Distance     Origin Pop  Destination Pop
# count   11886.000000  11886.000000   11886.000000     11886.000000
# mean      642.209322     42.754838   82359.672135    114811.445398
# std      3765.120726     36.680159  129656.123405    168339.275848
# min       100.000000      0.000000    1654.000000      1138.000000
# 25%       100.000000     17.000000   25054.000000     28628.000000
# 50%       100.000000     32.000000   41782.000000     52197.000000
# 75%       400.000000     57.000000   80683.000000    124451.000000
# max    272900.000000    260.000000  862965.000000    862965.000000
#
#                  Commuters  Distance  Origin Pop  Destination Pop
# Commuters         1.000000 -0.112738    0.101140         0.091014
# Distance         -0.112738  1.000000    0.167101         0.390472
# Origin Pop        0.101140  0.167101    1.000000        -0.057716
# Destination Pop   0.091014  0.390472   -0.057716         1.000000
#                      Commuters      Distance    Origin Pop  Destination Pop
# Commuters        1.417613e+07 -1.556976e+04  4.937348e+07     5.768631e+07
# Distance        -1.556976e+04  1.345434e+03  7.947010e+05     2.411052e+06
# Origin Pop       4.937348e+07  7.947010e+05  1.681071e+10    -1.259720e+09
# Destination Pop  5.768631e+07  2.411052e+06 -1.259720e+09     2.833811e+10
#
#
# Descriptive Statistics of 2019
#
#            Commuters      Distance     Origin Pop  Destination Pop
# count   11547.000000  11547.000000   11547.000000     11547.000000
# mean      675.145059     43.949597   86338.186629    117734.513553
# std      3972.886701     37.059894  132507.784774    170090.265902
# min       100.000000      0.000000    1704.000000       947.000000
# 25%       100.000000     18.000000   27008.000000     30801.000000
# 50%       100.000000     32.000000   44126.000000     55699.000000
# 75%       400.000000     59.000000   87086.000000    125099.000000
# max    282800.000000    262.000000  872757.000000    872757.000000
#
#                  Commuters  Distance  Origin Pop  Destination Pop
# Commuters         1.000000 -0.117128    0.097692         0.090716
# Distance         -0.117128  1.000000    0.173510         0.392144
# Origin Pop        0.097692  0.173510    1.000000        -0.058509
# Destination Pop   0.090716  0.392144   -0.058509         1.000000
#                      Commuters      Distance    Origin Pop  Destination Pop
# Commuters        1.578383e+07 -1.724527e+04  5.142891e+07     6.130117e+07
# Distance        -1.724527e+04  1.373436e+03  8.520588e+05     2.471889e+06
# Origin Pop       5.142891e+07  8.520588e+05  1.755831e+10    -1.318703e+09
# Destination Pop  6.130117e+07  2.471889e+06 -1.318703e+09     2.893070e+10
#
#
# Descriptive Statistics of 2020
#
#            Commuters      Distance     Origin Pop  Destination Pop
# count   11478.000000  11478.000000   11478.000000     11478.000000
# mean      668.278446     43.179909   86211.487629    117425.452431
# std      3835.398928     36.094458  133056.774280    170170.376600
# min       100.000000      0.000000    1726.000000      1194.000000
# 25%       100.000000     18.000000   26949.000000     30824.000000
# 50%       100.000000     32.000000   44341.000000     55220.000000
# 75%       400.000000     58.000000   85440.000000    124093.000000
# max    267100.000000    261.000000  873338.000000    873338.000000
#
#                  Commuters  Distance  Origin Pop  Destination Pop
# Commuters         1.000000 -0.119944    0.098305         0.092428
# Distance         -0.119944  1.000000    0.166022         0.401990
# Origin Pop        0.098305  0.166022    1.000000        -0.056716
# Destination Pop   0.092428  0.401990   -0.056716         1.000000
#                      Commuters      Distance    Origin Pop  Destination Pop
# Commuters        1.471028e+07 -1.660460e+04  5.016742e+07     6.032499e+07
# Distance        -1.660460e+04  1.302810e+03  7.973407e+05     2.469109e+06
# Origin Pop       5.016742e+07  7.973407e+05  1.770411e+10    -1.284192e+09
# Destination Pop  6.032499e+07  2.469109e+06 -1.284192e+09     2.895796e+10
