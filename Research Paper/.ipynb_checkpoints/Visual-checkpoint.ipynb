# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
def dropper(df):
    nan_value = float("NaN")
    df.replace(0.0, nan_value, inplace=True)
    return df

# %%
def get_info():
    df = pd.read_csv('Databases/Test_file.csv')
    df = dropper(df)
    df = df.dropna()
    return df

# %% [markdown]
# ## Note
# I need to ask Henry about the value of dropping the observation that contains intramunicipality commuting as opposed to keeping it, making distance decay stronger

# %%
def stat_plotter(df, i):
    
    # First Graph: Origin - Distance Plot
    plt.figure(figsize=(5, 5))
    ax = plt.axes()
    ax.scatter(df["Distance"], df["Origin Pop"], color='b', alpha=0.20)
    ax.set_xlabel('Distance')
    ax.set_ylabel('Origin Pop')
    plt.gcf()
    plt.savefig('Results/OrDistance' + str(i) + '.png')
    plt.close()
    
    # Second Graph: Destination - Distance Plot
    plt.figure(figsize=(5, 5))
    ax = plt.axes()
    ax.scatter(df["Distance"], df["Destination Pop"], color='b', alpha=0.20)
    ax.set_xlabel('Distance')
    ax.set_ylabel('Destination Pop')
    plt.gcf()
    plt.savefig('Results/DestDistance' + str(i) + '.png')
    plt.close()
    
    # Third Graph: Distance - Commuters Plot
    plt.figure(figsize=(5, 5))
    ax = plt.axes()
    ax.scatter(df["Distance"], df["Commuters"], color='b', alpha=0.20)
    ax.set_xlabel('Distance')
    ax.set_ylabel('Commuters')
    plt.gcf()
    plt.savefig('Results/DistCom' + str(i) + '.png')
    plt.close()
    
    # Fourth Graph: Destination - Commuters Plot
    plt.figure(figsize=(5, 5))
    ax = plt.axes()
    ax.scatter(df["Destination Pop"], df["Commuters"], color='b', alpha=0.20)
    ax.set_xlabel('Destination Pop')
    ax.set_ylabel('Commuters')
    plt.gcf()
    plt.savefig('Results/DestCom' + str(i) + '.png')
    plt.close()
    
    # Fifth Graph: Origin - Commuters Plot
    plt.figure(figsize=(5, 5))
    ax = plt.axes()
    ax.scatter(df["Origin Pop"], df["Commuters"], color='b', alpha=0.20)
    ax.set_xlabel('Origin Pop')
    ax.set_ylabel('Commuters')
    plt.gcf()
    plt.savefig('Results/OrCom' + str(i) + '.png')
    plt.close()

# %%
def descriptive_stats(input_df):
    df = input_df.copy()
    del df['Origin']
    del df['Destination']
    print(df.describe(), '\n')
    print(df.corr(), '\n', df.cov(), '\n\n')
    stat_plotter(df, "General")
    for i in range(2014, 2021, 1):
        print("Descriptive Statistics of %s \n" % i)
        df1 = df[df['Year'] == i]
        del df1['Year']
        print(df1.describe(), '\n')
        print(df1.corr(), '\n', df1.cov(), '\n\n')
        stat_plotter(df1, i)
    return

# %%
df = get_info()

# %%
descriptive_stats(df)
# Out:
#                Year     Commuters      Distance    Origin Pop  Destination Pop
# count  81750.000000  81750.000000  81750.000000  81750.000000     81750.000000
# mean    2016.990214      5.395676      3.406972     10.776064        11.034950
# std        1.993942      1.077943      0.925955      0.936414         1.030538
# min     2014.000000      4.605170     -2.302585      7.311886         6.823286
# 25%     2015.000000      4.605170      2.867899     10.137848        10.265941
# 50%     2017.000000      4.605170      3.459466     10.640053        10.832319
# 75%     2019.000000      5.991465      4.053523     11.310160        11.717685
# max     2020.000000     12.552495      5.714393     13.680078        13.680078
#
#                      Year  Commuters  Distance  Origin Pop  Destination Pop
# Year             1.000000   0.019585  0.021469    0.047038         0.031546
# Commuters        0.019585   1.000000 -0.541661    0.105339         0.133603
# Distance         0.021469  -0.541661  1.000000    0.271454         0.466613
# Origin Pop       0.047038   0.105339  0.271454    1.000000        -0.022417
# Destination Pop  0.031546   0.133603  0.466613   -0.022417         1.000000
#                       Year  Commuters  Distance  Origin Pop  Destination Pop
# Year             3.975806   0.042095  0.039638    0.087828         0.064821
# Commuters        0.042095   1.161960 -0.540646    0.106330         0.148414
# Distance         0.039638  -0.540646  0.857392    0.235372         0.445257
# Origin Pop       0.087828   0.106330  0.235372    0.876871        -0.021633
# Destination Pop  0.064821   0.148414  0.445257   -0.021633         1.062008
#
#
# Descriptive Statistics of 2014
#
#           Commuters      Distance    Origin Pop  Destination Pop
# count  11719.000000  11719.000000  11719.000000     11719.000000
# mean       5.365476      3.382051     10.719109        10.995857
# std        1.055887      0.949091      0.964508         1.054084
# min        4.605170     -2.302585      7.319202         7.319202
# 25%        4.605170      2.821379     10.073315        10.194065
# 50%        4.605170      3.427515     10.568210        10.783446
# 75%        5.703782      4.048301     11.284908        11.708180
# max       12.417953      5.714393     13.619194        13.619194
#
#                  Commuters  Distance  Origin Pop  Destination Pop
# Commuters         1.000000 -0.527419    0.106391         0.132056
# Distance         -0.527419  1.000000    0.283196         0.472810
# Origin Pop        0.106391  0.283196    1.000000        -0.033197
# Destination Pop   0.132056  0.472810   -0.033197         1.000000
#                   Commuters  Distance  Origin Pop  Destination Pop
# Commuters         1.114897 -0.528544    0.108350         0.146977
# Distance         -0.528544  0.900774    0.259240         0.473009
# Origin Pop        0.108350  0.259240    0.930276        -0.033750
# Destination Pop   0.146977  0.473009   -0.033750         1.111092
#
#
# Descriptive Statistics of 2015
#
#           Commuters      Distance    Origin Pop  Destination Pop
# count  11651.000000  11651.000000  11651.000000     11651.000000
# mean       5.376920      3.393245     10.742524        11.007712
# std        1.059983      0.938152      0.948015         1.043280
# min        4.605170     -2.302585      7.311886         6.823286
# 25%        4.605170      2.839078     10.107081        10.220741
# 50%        4.605170      3.440418     10.588023        10.789443
# 75%        5.991465      4.053523     11.339143        11.716136
# max       12.456053      5.569108     13.633538        13.633538
#
#                  Commuters  Distance  Origin Pop  Destination Pop
# Commuters         1.000000 -0.535783    0.102946         0.136450
# Distance         -0.535783  1.000000    0.274207         0.466409
# Origin Pop        0.102946  0.274207    1.000000        -0.027250
# Destination Pop   0.136450  0.466409   -0.027250         1.000000
#                   Commuters  Distance  Origin Pop  Destination Pop
# Commuters         1.123564 -0.532796    0.103448         0.150895
# Distance         -0.532796  0.880130    0.243875         0.456500
# Origin Pop        0.103448  0.243875    0.898733        -0.026952
# Destination Pop   0.150895  0.456500   -0.026952         1.088434
#
#
# Descriptive Statistics of 2016
#
#           Commuters      Distance    Origin Pop  Destination Pop
# count  11702.000000  11702.000000  11702.000000     11702.000000
# mean       5.382419      3.393307     10.745805        11.014307
# std        1.069176      0.931073      0.943216         1.039482
# min        4.605170     -2.302585      7.311886         6.846943
# 25%        4.605170      2.850707     10.103485        10.230198
# 50%        4.605170      3.433987     10.614204        10.805679
# 75%        5.991465      4.041295     11.288882        11.725299
# max       12.460715      5.561451     13.647029        13.647029
#
#                  Commuters  Distance  Origin Pop  Destination Pop
# Commuters         1.000000 -0.537634    0.108763         0.133103
# Distance         -0.537634  1.000000    0.270468         0.471886
# Origin Pop        0.108763  0.270468    1.000000        -0.013488
# Destination Pop   0.133103  0.471886   -0.013488         1.000000
#                   Commuters  Distance  Origin Pop  Destination Pop
# Commuters         1.143138 -0.535205    0.109683         0.147929
# Distance         -0.535205  0.866897    0.237526         0.456707
# Origin Pop        0.109683  0.237526    0.889657        -0.013225
# Destination Pop   0.147929  0.456707   -0.013225         1.080522
#
#
# Descriptive Statistics of 2017
#
#           Commuters      Distance    Origin Pop  Destination Pop
# count  11793.000000  11793.000000  11793.000000     11793.000000
# mean       5.393970      3.390615     10.761132        11.014108
# std        1.077212      0.918002      0.947073         1.034162
# min        4.605170     -2.302585      7.362011         6.837333
# 25%        4.605170      2.862201     10.123065        10.240460
# 50%        4.605170      3.440418     10.617589        10.816874
# 75%        5.991465      4.032469     11.297167        11.717685
# max       12.491627      5.560297     13.657742        13.657742
#
#                  Commuters  Distance  Origin Pop  Destination Pop
# Commuters         1.000000 -0.540453    0.104554         0.137094
# Distance         -0.540453  1.000000    0.281016         0.468758
# Origin Pop        0.104554  0.281016    1.000000        -0.009992
# Destination Pop   0.137094  0.468758   -0.009992         1.000000
#                   Commuters  Distance  Origin Pop  Destination Pop
# Commuters         1.160386 -0.534444    0.106666         0.152725
# Distance         -0.534444  0.842727    0.244319         0.445021
# Origin Pop        0.106666  0.244319    0.896948        -0.009787
# Destination Pop   0.152725  0.445021   -0.009787         1.069492
#
#
# Descriptive Statistics of 2018
#
#           Commuters      Distance    Origin Pop  Destination Pop
# count  11877.000000  11877.000000  11877.000000     11877.000000
# mean       5.400941      3.411212     10.771668        11.039445
# std        1.084123      0.921769      0.933224         1.030146
# min        4.605170     -2.302585      7.410952         7.037028
# 25%        4.605170      2.879198     10.134560        10.262141
# 50%        4.605170      3.465736     10.640221        10.862780
# 75%        5.991465      4.055257     11.298283        11.735261
# max       12.516861      5.562219     13.668129        13.668129
#
#                  Commuters  Distance  Origin Pop  Destination Pop
# Commuters         1.000000 -0.538854    0.111292         0.133834
# Distance         -0.538854  1.000000    0.264905         0.470745
# Origin Pop        0.111292  0.264905    1.000000        -0.024325
# Destination Pop   0.133834  0.470745   -0.024325         1.000000
#                   Commuters  Distance  Origin Pop  Destination Pop
# Commuters         1.175323 -0.538483    0.112597         0.149466
# Distance         -0.538483  0.849657    0.227876         0.446999
# Origin Pop        0.112597  0.227876    0.870907        -0.023385
# Destination Pop   0.149466  0.446999   -0.023385         1.061201
#
#
# Descriptive Statistics of 2019
#
#           Commuters      Distance    Origin Pop  Destination Pop
# count  11540.000000  11540.000000  11540.000000     11540.000000
# mean       5.424343      3.444174     10.847797        11.089842
# std        1.100725      0.916247      0.905151         1.003860
# min        4.605170     -2.302585      7.440734         6.853299
# 25%        4.605170      2.923162     10.203888        10.335302
# 50%        4.605170      3.496508     10.694804        10.927717
# 75%        5.991465      4.079231     11.374651        11.736861
# max       12.552495      5.569108     13.679412        13.679412
#
#                  Commuters  Distance  Origin Pop  Destination Pop
# Commuters         1.000000 -0.558532    0.097768         0.127284
# Distance         -0.558532  1.000000    0.263929         0.458837
# Origin Pop        0.097768  0.263929    1.000000        -0.029367
# Destination Pop   0.127284  0.458837   -0.029367         1.000000
#                   Commuters  Distance  Origin Pop  Destination Pop
# Commuters         1.211596 -0.563299    0.097409         0.140645
# Distance         -0.563299  0.839508    0.218887         0.422030
# Origin Pop        0.097409  0.218887    0.819298        -0.026684
# Destination Pop   0.140645  0.422030   -0.026684         1.007734
# Descriptive Statistics of 2020
#
#           Commuters      Distance    Origin Pop  Destination Pop
# count  11468.000000  11468.000000  11468.000000     11468.000000
# mean       5.426578      3.435326     10.846940        11.085179
# std        1.097008      0.904596      0.902842         1.002820
# min        4.605170     -2.302585      7.453562         7.085064
# 25%        4.605170      2.917771     10.203925        10.336049
# 50%        4.605170      3.490429     10.700048        10.919080
# 75%        5.991465      4.060874     11.355570        11.728787
# max       12.495378      5.565669     13.680078        13.680078
#
#                  Commuters  Distance  Origin Pop  Destination Pop
# Commuters         1.000000 -0.560151    0.099853         0.131832
# Distance         -0.560151  1.000000    0.254867         0.452323
# Origin Pop        0.099853  0.254867    1.000000        -0.032454
# Destination Pop   0.131832  0.452323   -0.032454         1.000000
#                   Commuters  Distance  Origin Pop  Destination Pop
# Commuters         1.203425 -0.555865    0.098897         0.145029
# Distance         -0.555865  0.818293    0.208151         0.410323
# Origin Pop        0.098897  0.208151    0.815123        -0.029383
# Destination Pop   0.145029  0.410323   -0.029383         1.005647
